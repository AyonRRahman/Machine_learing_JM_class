# %%
#importing libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
#Question 2

def load_data(filepath: str) -> pd.DataFrame:
    """
    return a pandas DataFrame from a given file
    
    arguments -- the full path to the file containing the data
    return -- A pandas DataFrame
    """
    # open the file and read lines
    with open('Boston Dataset.csv','r') as f:
            lines = f.readlines()

    flag = 0               #check if we reached to variables name
    flag1 = 0              #check if we reached the last of the variables name
    column_names = []      #store the column names of the df in a list
    rows = []              #record the rows of the df
        
    for line in lines:     #parse the lines

        if 'Variables in order:' in line:
            flag = 1 #start recording column names
            continue


        if flag==0:
            continue #skip all the lines before variable names

        if flag==1 and flag1==0 : #check if we are in the variables names part
            
            #we only need the first word. So splitting and taking the first word. 
            
            line = line.split()
            if len(line)>0:
                column_names.append(line[0])
            
            if 'MEDV' in line:
                flag1 = 1 #reached the last of the variable names

            continue
        
        #if we reached the last variable names then start to record rows
        
        if flag == 1:
            line = line.split() #split the lines to get different values
            # the rows are splitted between 2 successive rows. The lengths are 11 and 3
            # when we get the line with 11 words, we append it to the rows list and if we get 3 words,
            # we add this to the last row
            
            if len(line)==11:
                rows.append(line)
            if len(line)==3:
                rows[-1] += line 

    df = pd.DataFrame(rows, columns = column_names) #create the dataframe with the column names and rows
    
    return df

#call the function and display first 10 rows
df = load_data('Boston Dataset.csv')
df = df.astype('float64')
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
#question 3
#plotting y against all columns 
#using subplots to plot all the columns in a single figure
fig, axs = plt.subplots(4,4,figsize=(50,30)) 
#i and j for indexing the subplots
i = 0 #column index
j = 0 #row index
y = df['MEDV'].to_list()

for col in df: #iterate over all the columns
    if col=='MEDV': # we dont want to plot y against y
        continue
    x = df[col].to_list()
    
    
    if j>3: 
        #we have 4 columns so we are increasing the value of i if we exceed 3 and resetting j=0
        i+=1
        j=0
    #ploting on the subplot
    axs[i,j].scatter(x,y)
    axs[i,j].set_title(col)
    j+=1

# %%
#q3 choosing the single best column
#calculating correlations with the output to select the single best column
column_names = df.columns.to_list()
y_name = 'MEDV' #column of interest
correlation_df = df.corr()
correlation_df.loc[correlation_df[y_name].idxmax()]
#LSTAT has the maximum correlation so we use this in the model
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
#question 4
def lm(x, y):
    """
    takes x and y as a list and returns the best fit line parameter m and b
    
    params: 
    x -- input 
    y -- output of the model
    
    return:
    m -- slope of the line
    b -- y intercept
    """
    m = random.randint(1,9)
    b = random.randint(1,9)
    # create random m, b
    return m, b

# %%
#question 5
#taking x and y as list
y = df['MEDV'].to_list()
x = df['LSTAT'].to_list()
m, b = lm(x, y) #get m and b from the function
y_pred = [] #list for recording predictions
for xi in x:
    y_pred.append(m*xi + b) #calculate predictions with the m and b

print(m)
print(b)
print(len(y))
print(len(y_pred))
# Out:
# 1
# 2
# 506
# 506

# %%
#ques 6
def mae(y, y_pred) -> float:
    """
    takes two list and returns the mean absolute error between them
    
    params:
    y, y_pred -- two list 
    
    returns -- the mean absolute error between y and y_pred 
    """
    # calculate the mean absolute error
    error_list = np.array(y) - np.array(y_pred) #calculating the error
    error_list = abs(error_list) #take the absolute value
    error = np.mean(error_list) #take the mean
    return error

mae(y,y_pred)
# Out:
# 13.571600790513832

# %%
#ques 7
plt.scatter(x,y)
plt.plot(x, y_pred, color='red')

# %%
#ques 8
def lm(x, y):
    """
    takes x and y as a list and returns the best fit line parameter m and b
    
    params: 
    x -- input 
    y -- output of the model
    
    return:
    m -- slope of the line
    b -- y intercept
    """
    N = len(x)
    m = (N*(np.dot(x,y)) - sum(x)*sum(y))/(N*(np.dot(x,x)) -sum(x)**2) #using least square method formula
    b = (sum(y) - m*sum(x))/N
    
    return m, b

# %%
#ques 9
#predicting on the new m and b and ploting
y = df['MEDV'].to_list()
x = df['LSTAT'].to_list()
m, b = lm(x, y)
y_pred = []
for xi in x:
    y_pred.append(m*xi + b)

print(m)
print(b)
print(len(y))
print(len(y_pred))
plt.scatter(x,y)
plt.plot(x, y_pred, color = 'red')
# Out:
# -0.950049353758005
# 34.55384087938331
# 506
# 506

# %%
#ques 10 new mean abs error with new value of m and b
mae(y,y_pred)
# Out:
# 4.5052811662505805
